# %%
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head =None

  def append(self,value):
    new_node = Node(value)
    if self.head == None:
      self.head = new_node
    else:
      curr = self.head
      while curr.next is not None:
        curr = curr.next
      curr.next = new_node
  def traversal(self):
    if self.head is None:
      print('SLL is empty')
    else:
      curr = self.head
      while curr is not None:
        print(curr.value,end=" ")
        curr = curr.next

  def insert(self,value,pos):
    new_node = Node(value)

    if pos ==0:
      new_node.next = self.head
      self.head = new_node
    else:
      curr = self.head
      prev_node = None
      count =0
      while curr is not None and count < pos:
        prev_node = curr
        curr = curr.next
        count +=1
      prev_node.next = new_node
      new_node.next = curr


  def delete(self,value):
    temp = self.head
    if temp.next is not None:
      if temp.value == value:
        self.head = temp.next
        return
      else:
        found = False
        prev = None
        while temp is not None:
          if temp.value == value:
            found = True
            break
          prev = temp
          temp = temp.next
        if found:
          prev.next = temp.next
          return
        else:
          print("No node found")


# Brute force
  # def middle(self):
  #     count = 0
  #     temp= self.head
  #     while temp is not None:
  #          count+=1
  #          temp = temp.next
  #          for i in range(0,count//2):
  #              temp = temp.next
  #          return temp.value
  #tortoise rabbit method


  def middle(self):
    slow = self.head
    fast = self.head
    while fast is not None and fast.next is not None:
      slow = slow.next
      fast = fast.next.next
    return slow.value

  
  # reverse brute force
  # def reverse(self):
  #   temp = self.head
  #   stack = []
  #   while temp is not None:
  #     stack.append(temp.value)
  #     temp= temp.next
  #   temp = self.head
  #   while temp is not None:
  #     e = stack.pop()
  #     temp.value = e
  #     temp= temp.next
  #   return self.head
  
  # optimal
  def reverse(self):
    prev = None
    temp= self.head
    while temp is not None:
      front = temp.next
      temp.next = prev
      prev = temp
      temp = front
    self.head = prev

  def display(self):
    temp = self.head

    while temp is not None:
        print(temp.value, end=" ")
        temp = temp.next
    print()


      
      
ssl = SinglyLinkedList()
ssl.append(23)
ssl.append(34)
ssl.append(54)
ssl.append(43)
# ssl.middle()
# ssl.delete(34)
# ssl.insert(25,1)
# ssl.traversal()

# ---------------------------------

ssl.reverse()
ssl.display()
# ---------------------------------
# Out:
# 43 54 34 23

# %% [markdown]
# Cycle exists or not

# %%
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head =None

  def append(self,value):
    new_node = Node(value)
    if self.head == None:
      self.head = new_node
    else:
      curr = self.head
      while curr.next is not None:
        curr = curr.next
      curr.next = new_node
  def traversal(self):
    if self.head is None:
      print('SLL is empty')
    else:
      curr = self.head
      while curr is not None:
        print(curr.value,end=" ")
        curr = curr.next

# cycle check bruteforce
  # def check_cycle(self):
  #   temp = self.head
  #   my_set = set()
  #   while temp is not None:
  #     if temp in my_set:
  #       return True
  #     my_set.add(temp)
  #     temp = temp.next
  #   return False


  # optimal
  # def check_cycle(self):
  #   slow = self.head
  #   fast = self.head
  #   while fast is not None and fast.next is not None:
  #     slow = slow.next
  #     fast = fast.next.next
  #     if slow == fast:
  #       return True
  #   return False
# 
# optimal
  def cycle_meet_point(self):
      slow = self.head
      fast = self.head
      while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
          slow = self.head
  
          while slow != fast:
            slow = slow.next
            fast = fast.next
          return slow.value
      return None
  

  # brute force
  # def length_of_cycle(self):
  #   temp = self.head
  #   my_dict = dict()
  #   travel =0
  #   while temp is not None:
  #     if temp in my_dict:
  #       return travel - my_dict[temp]
  #     travel+=1
  #     my_dict[temp]= travel
  #     temp= temp.next
  #   return 0
# optimal
  def length_of_cycle(self):
    slow = self.head 
    fast = self.head
    while fast is not None and fast.next is not None:
      slow = slow.next
      fast = fast.next.next
      if slow == fast:
         slow = slow.next
         count=1
         while slow !=fast:
           slow = slow.next
           count+=1
         return count
    return None
  # brute force
  def odd_even(self):
    if self.head is None or self.head.next is None:
      return self.head 
    values =[]
    temp = self.head
    while temp and temp.next:
      values.append(temp.value)
      temp = temp.next.next
    temp = self.head.next
    while temp and temp.next:
      values.append(temp.value)
    temp = self.head.next
    return values


  





 
      
      
ssl = SinglyLinkedList()
ssl.append(23)
ssl.append(34)
ssl.append(54)
ssl.append(43)
ssl.append(34)

# ssl.traversal()
ssl.head.next.next.next.next = ssl.head.next

# ssl.cycle_meet_point()
# ssl.length_of_cycle()
ssl.odd_even()
# if ssl.check_cycle():
#     print("Cycle detected")
# else:
#     print("No cycle")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 132
#     128 ssl.head.next.next.next.next = ssl.head.next
#     129
#     130 # ssl.cycle_meet_point()
#     131 # ssl.length_of_cycle()
# --> 132 ssl.odd_even()
#     133 # if ssl.check_cycle():
#     134 #     print("Cycle detected")
#     135 # else:
#
# Cell In[5], line 102, in SinglyLinkedList.odd_even(self)
#      98       return self.head
#      99     values =[]
#     100     temp = self.head
#     101     while temp and temp.next:
# --> 102       values.append(temp.value)
#     103       temp = temp.next.next
#     104     temp = self.head.next
#     105     while temp and temp.next:
#
# KeyboardInterrupt:
