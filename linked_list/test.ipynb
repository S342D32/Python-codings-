# %%
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head =None

  def append(self,value):
    new_node = Node(value)
    if self.head == None:
      self.head = new_node
    else:
      curr = self.head
      while curr.next is not None:
        curr = curr.next
      curr.next = new_node
  def traversal(self):
    if self.head is None:
      print('SLL is empty')
    else:
      curr = self.head
      while curr is not None:
        print(curr.value,end=" ")
        curr = curr.next

  def insert(self,value,pos):
    new_node = Node(value)

    if pos ==0:
      new_node.next = self.head
      self.head = new_node
    else:
      curr = self.head
      prev_node = None
      count =0
      while curr is not None and count < pos:
        prev_node = curr
        curr = curr.next
        count +=1
      prev_node.next = new_node
      new_node.next = curr


  def delete(self,value):
    temp = self.head
    if temp.next is not None:
      if temp.value == value:
        self.head = temp.next
        return
      else:
        found = False
        prev = None
        while temp is not None:
          if temp.value == value:
            found = True
            break
          prev = temp
          temp = temp.next
        if found:
          prev.next = temp.next
          return
        else:
          print("No node found")


# Brute force
  # def middle(self):
  #     count = 0
  #     temp= self.head
  #     while temp is not None:
  #          count+=1
  #          temp = temp.next
  #          for i in range(0,count//2):
  #              temp = temp.next
  #          return temp.value
  #tortoise rabbit method


  def middle(self):
    slow = self.head
    fast = self.head
    while fast is not None and fast.next is not None:
      slow = slow.next
      fast = fast.next.next
    return slow.value

  
  # reverse brute force
  # def reverse(self):
  #   temp = self.head
  #   stack = []
  #   while temp is not None:
  #     stack.append(temp.value)
  #     temp= temp.next
  #   temp = self.head
  #   while temp is not None:
  #     e = stack.pop()
  #     temp.value = e
  #     temp= temp.next
  #   return self.head
  
  # optimal
  def reverse(self):
    prev = None
    temp= self.head
    while temp is not None:
      front = temp.next
      temp.next = prev
      prev = temp
      temp = front
    self.head = prev

  def display(self):
    temp = self.head

    while temp is not None:
        print(temp.value, end=" ")
        temp = temp.next
    print()


      
      
ssl = SinglyLinkedList()
ssl.append(23)
ssl.append(34)
ssl.append(54)
ssl.append(43)
# ssl.middle()
# ssl.delete(34)
# ssl.insert(25,1)
# ssl.traversal()

# ---------------------------------

ssl.reverse()
ssl.display()
# ---------------------------------
# Out:
# 43 54 34 23

# %% [markdown]
# Cycle exists or not

# %%
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head =None

  def append(self,value):
    new_node = Node(value)
    if self.head == None:
      self.head = new_node
    else:
      curr = self.head
      while curr.next is not None:
        curr = curr.next
      curr.next = new_node
  def traversal(self):
    if self.head is None:
      print('SLL is empty')
    else:
      curr = self.head
      while curr is not None:
        print(curr.value,end=" ")
        curr = curr.next

# cycle check bruteforce
  # def check_cycle(self):
  #   temp = self.head
  #   my_set = set()
  #   while temp is not None:
  #     if temp in my_set:
  #       return True
  #     my_set.add(temp)
  #     temp = temp.next
  #   return False


  # optimal
  # def check_cycle(self):
  #   slow = self.head
  #   fast = self.head
  #   while fast is not None and fast.next is not None:
  #     slow = slow.next
  #     fast = fast.next.next
  #     if slow == fast:
  #       return True
  #   return False
# 
# optimal
  def cycle_meet_point(self):
      slow = self.head
      fast = self.head
      while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
          slow = self.head
  
          while slow != fast:
            slow = slow.next
            fast = fast.next
          return slow.value
      return None
  

  # brute force
  # def length_of_cycle(self):
  #   temp = self.head
  #   my_dict = dict()
  #   travel =0
  #   while temp is not None:
  #     if temp in my_dict:
  #       return travel - my_dict[temp]
  #     travel+=1
  #     my_dict[temp]= travel
  #     temp= temp.next
  #   return 0
# optimal
  def length_of_cycle(self):
    slow = self.head 
    fast = self.head
    while fast is not None and fast.next is not None:
      slow = slow.next
      fast = fast.next.next
      if slow == fast:
         slow = slow.next
         count=1
         while slow !=fast:
           slow = slow.next
           count+=1
         return count
    return None
  # brute force
  # def odd_even(self):
  #   if self.head is None or self.head.next is None:
  #       return self.head

  #   values = []

  #   # Odd positions
  #   temp = self.head
  #   while temp:
  #       values.append(temp.value)
  #       temp = temp.next.next if temp.next else None

  #   # Even positions
  #   temp = self.head.next
  #   while temp:
  #       values.append(temp.value)
  #       temp = temp.next.next if temp.next else None

  #   # Put values back
  #   temp = self.head
  #   index = 0
  #   while temp:
  #       temp.value = values[index]
  #       index += 1
  #       temp = temp.next
  #   return self.head

  # optimal
  def odd_even(self):
    if self.head is None or self.head.next is None:
      return self.head
    odd = self.head
    even = self.head.next
    even_hd = even
    while even is not None and even.next is not None:
      odd.next = odd.next.next
      odd = odd.next
      even.next = even.next.next
      even = even.next
    odd.next = even_hd
    return self.head
  # optimal
  def nth_ele_delete(self,n):
    slow = self.head
    fast = self.head
    for _ in range(n):
      fast = fast.next
    if fast == None:
      return self.head.next
    while fast.next is not None:
      slow = slow.next
      fast = fast.next
    slow.next = slow.next.next
    return self.head

  




  





 
      
      
ssl = SinglyLinkedList()
ssl.append(23)
ssl.append(34)
ssl.append(54)
ssl.append(43)
ssl.append(34)

# ssl.traversal()
# ssl.head.next.next.next.next = ssl.head.next

# ssl.cycle_meet_point()
# ssl.length_of_cycle()
ssl.odd_even()
ssl.traversal()
# if ssl.check_cycle():
#     print("Cycle detected")
# else:
#     print("No cycle")
# Out:
# 23 54 34 34 43

# %% [markdown]
# Doubly Linked List

# %%
class Node:
  def __init__(self,val):
    self.val = val
    self.next = None
    self.prev = None

class DoublyLinkedList:
  def __init__(self):
    self.head = None
  def insert_at_head(self,val):
    new_node = Node(val)
    if not self.head:
      self.head = new_node
    else:
      new_node.next = self.head
      self.head.prev = new_node
      self.head = new_node

  def append(self,val):
    new_node = Node(val)
    if self.head is None:
      self.head = new_node
    else:
      curr= self.head
      while curr.next:
        curr = curr.next
      curr.next = new_node
      new_node.prev = curr

  def insert_at_pos(self,val,pos):
    new_node = Node(val)
    if pos == 0:
       new_node.next = self.head
       if self.head:
        self.head.prev = new_node
       self.head = new_node
    return
    curr= self.head
    count =0
    while curr and count < pos-1:
      curr = curr.next
      count+=1
    if curr is None:
      print("Position out of bound.")

    new_node.next = curr.next
    new_node.prev = curr
    if curr.next:
      curr.next.prev = new_node
    curr.next = new_node

# Brute force
  # def reverse(self):
  #   stack = []
  #   temp= self.head
  #   while temp is not None:
  #     stack.append(temp.val)
  #     temp = temp.next
  #   temp = self.head
  #   while temp is not None:
  #     e = stack.pop()
  #     temp.val = e
  #     temp = temp.next
# optimal solution
  def reverse(self):
    if self.head is None and self.head.next is None:
      return self.head
    curr =self.head
    prev = None

    while curr is not None:
      front = curr.next
      curr.next = prev
      curr.prev = front
      prev = curr
      curr = front
    self.head = prev
  def delete(self,k):
    if self.head.next is None and self.head.val ==k:
      return None
    temp = self.head
    prev = None
    new_head = temp
    while temp is not None:
      if temp.val == k:
        if prev is not None:
          prev.next = temp.next
        if temp.next is not None:
          temp.next.prev =  prev
        if temp == new_head:
          new_head = new_head.next
      prev = temp
      temp = temp.next
    return new_head
  
# pair finding in DLL
# BruteForce
  # def pairs_target(self,target):
  #   temp = self.head
  #   result =[]
  #   while temp is not None:
  #     front = temp.next
  #     while front is not None:
  #       if temp.val + front.val == target:
  #         result.append([temp.val,front.val])
  #       front = front.next
  #     temp = temp.next
  #   return result
  # O(N^2),O(1)
  # ------------------------------
  # better
  # def pairs_target(self,target):
  #   my_set = set()
  #   temp = self.head
  #   result=[]
  #   while temp is not None:
  #     remaining = target-temp.val
  #     if remaining in my_set:
  #       result.append([remaining,temp.val])
  #     my_set.add(temp.val)
  #     temp = temp.next
  #   return result
  # O(N),O(N)
  # optimal
  # ---------------------------------
  def pairs_target(self,target):
    result =[]
    left = self.head
    right = self.head
    while right.next is not None:
      right = right.next
    while left is not None and right is not None and left.val < right.val:
      total = left.val + right.val
      if total == target:
        result.append([left.val,right.val])
        left =  left.next
        right = right.prev
      elif total > target:
        right = right.prev
      else:
        left = left.next
    return result
  # O(N)+O(N) = O(2N)= O(N),O(1)
  def remove_duplicate(self):

    if self.head is None or self.head.next is None:
        return self.head

    curr = self.head.next

    while curr is not None:

        if curr.val == curr.prev.val:

            if curr.prev == self.head:
                self.head = curr
                curr.prev = None

            else:
                curr.prev.prev.next = curr
                curr.prev = curr.prev.prev

        else:
            curr = curr.next

    return self.head
  
  







  def traverse_forward(self):
    curr = self.head

    if curr is None:
        print("No elements found")
        return

    while curr is not None:
        print(curr.val,end="<-->")
        curr = curr.next




dll = DoublyLinkedList()

dll.append(10)
dll.append(20)
dll.append(30)
dll.append(30)
dll.append(40)
# dll.reverse()
# dll.delete(30)
# print(dll.pairs_target(50))
dll.remove_duplicate()
# dll.insert_at_pos(50,2)
dll.traverse_forward()
# Out:
# 10<-->20<-->30<-->40<-->
