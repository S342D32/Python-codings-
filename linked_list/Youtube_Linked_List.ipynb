# %% [markdown]
# Create a Node and linkedlist

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def __len__(self):
        return self.n

    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
        else:
            curr = self.head
            while curr.next is not None:
                curr = curr.next
            curr.next = new_node
        
    def traverse(self):
        curr = self.head
        while curr is not None:
            print(curr.value, end=' ')
            curr = curr.next
        print()

    def reverse(self):
        prev = None
        curr = self.head
        while curr is not None:
            next_node = curr.next
            curr.next = prev
            prev = curr
            curr = next_node
        self.head = prev


    def starting_point_in_cycle(self):
        slow = self.head
        fast = self.head

    # Step 1: Detect cycle
        while fast is not None and fast.next is not None:
              slow = slow.next
              fast = fast.next.next

              if slow == fast:
            # Step 2: Find starting point
                 slow = self.head
                 while slow != fast:
                      slow = slow.next
                      fast = fast.next
                 return slow

        return None
    def length_loop_in_cycle(self):
        slow = self.head
        fast = self.head

    # Step 1: Detect cycle
        while fast is not None and fast.next is not None:
              slow = slow.next
              fast = fast.next.next
              count=1

              if slow == fast:
            # Step 2: Find starting point
                 slow= slow.next
                 while slow != fast:
                     slow = slow.next
                     count+=1
                 return count
        return None
        
     # first odd then even will print 
    def odd_even(self):
        odd = self.head
        even = odd.next
        even_head = even
        while even is not None and even.next is not None:
            odd.next = odd.next.next
            odd = odd.next
            even.next = even.next.next
            even = even.next
        odd.next = even_head
        return self.head




# Example usage
ll = SinglyLinkedList()
ll.append(1)
ll.append(2)
ll.append(3)
ll.append(4)
ll.append(1)

# Go to last node for cycle
# curr = ll.head
# while curr.next:
#     curr = curr.next

# Create cycle: 5 → 3
# curr.next = ll.head.next.next


# print("Linked List:")
# ll.traverse()  # Output: 1 2 3 4

# ll.reverse()
# print("Reversed Linked List:")
# ll.traverse()  # Output: 4 3 2 1

# start = ll.starting_point_in_cycle()
# if start:
#     print("Cycle starts at:", start.value)
# else:
#     print("No cycle found")


# start = ll.length_loop_in_cycle()
# if start:
#     print("total loop exist :", start)
# else:
#     print("No cycle found")

start = ll.odd_even()
if start:
    print("odd_even :", start)
else:
    print("No cycle found")
# Out:
# odd_even : <__main__.Node object at 0x000001282E23D350>

# %% [markdown]
# Character space
