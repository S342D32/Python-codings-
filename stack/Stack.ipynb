# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.next = None

class Stack:
    def __init__(self):
        self.top = None

    def isempty(self):
        return self.top is None

    def push(self, value):
        new_node = Node(value)
        new_node.next = self.top
        self.top = new_node

    def pop(self):
        if self.isempty():
            return None
        else:
            popped_value = self.top.data
            self.top = self.top.next
            return popped_value

    def reverse_string(self, string):
        # Push each character of the string onto the stack
        for char in string:
            self.push(char)

        # Pop each character from the stack to get them in reverse order
        reversed_string = ''
        while not self.isempty():
            reversed_string += self.pop()

        return reversed_string

# Example usage
s = Stack()
original_string = "hello"
reversed_string = s.reverse_string(original_string)

print("Original String:", original_string)
print("Reversed String:", reversed_string)
# Out:
# Original String: hello
# Reversed String: olleh

# %%
s =stack()

# %%
s.isempty()
# Out:
# True

# %%
s.push(2)
s.push(6)
s.push(7)
s.push(8)

# %%
s.traverse()
# Out:
# 8
# 7
# 6
# 2

# %%
s.peak()
# Out:
# 8

# %%
s.count()
# Out:
# 4

# %%
s.count()
# Out:
# 4

# %% [markdown]
# Text editor

# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.next = None

class Stack:
    def __init__(self):
        self.top = None

    def isempty(self):
        return self.top is None

    def push(self, value):
        new_node = Node(value)
        new_node.next = self.top
        self.top = new_node

    def pop(self):
        if self.isempty():
            return None
        else:
            popped_value = self.top.data
            self.top = self.top.next
            return popped_value

def text_editor(text, pattern):
    u = Stack()
    r = Stack()
    res = ""

    # Push each character of the text onto the undo stack
    for char in text:
        u.push(char)

    # Process the pattern
    for char in pattern:
        if char == 'u':  # Assuming 'u' signifies an undo action
            data = u.pop()
            if data is not None:
                r.push(data)
        else:  # Assuming any other character signifies a redo action
            data = r.pop()
            if data is not None:
                u.push(data)

    # Create the resulting string from the undo stack
    while not u.isempty():
        res = u.pop() + res  # Build the result string in reverse order

    print(res)

# Example usage
text_editor("Hello", "uuuu")
# Out:
# H

# %%
L =[ 
    [0,0,1,1],
    [0,0,1,0],
    [0,0,0,0],
    [1,0,1,0]
]

# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.next = None

class Stack:
    def __init__(self):
        self.top = None

    def isempty(self):
        return self.top is None

    def push(self, value):
        new_node = Node(value)
        new_node.next = self.top
        self.top = new_node

    def pop(self):
        if self.isempty():
            return None
        else:
            popped_value = self.top.data
            self.top = self.top.next
            return popped_value

    def size(self):
        count = 0
        temp = self.top
        while temp is not None:
            count += 1
            temp = temp.next
        return count

def find_celebrity(L):
    s = Stack()
    for i in range(len(L)):
        s.push(i)

    while s.size() >= 2:
        i = s.pop()
        j = s.pop()
        if L[i][j] == 0:
            s.push(i)
        else:
            s.push(j)

    candidate = s.pop()

    for i in range(len(L)):
        if i != candidate and (L[i][candidate] == 0 or L[candidate][i] == 1):
            return "No celebrity"

    return candidate

L = [
    [0, 0, 1, 1],
    [0, 0, 1, 0],
    [0, 0, 0, 0],
    [1, 0, 1, 0]
]

celebrity = find_celebrity(L)
print("Celebrity:", celebrity)
# Out:
# Celebrity: 2

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return len(self.stack) == 0

    def push(self, value):
        self.stack.append(value)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            return None

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            return None

def is_balanced_parentheses(expression):
    stack = Stack()
    matching_parentheses = {')': '(', '}': '{', ']': '['}
    
    for char in expression:
        if char in matching_parentheses.values():
            stack.push(char)
        elif char in matching_parentheses.keys():
            if stack.is_empty() or stack.pop() != matching_parentheses[char]:
                return False
    
    return stack.is_empty()

# Example usage
expression = "{[((45tt555)hyyy)]}"
if is_balanced_parentheses(expression):
    print(f"The expression '{expression}' is balanced.")
else:
    print(f"The expression '{expression}' is not balanced.")
# Out:
# The expression '{[((45tt555)hyyy)]}' is balanced.
